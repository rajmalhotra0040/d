# %%
df= df.drop(columns=['Pregnancies', 'SkinThickness','DiabetesPedigreeFunction','Insulin', 'Outcome'])
df
# Out:
#      Glucose  BloodPressure   BMI  Age
# 0        148             72  33.6   50
# 1         85             66  26.6   31
# 2        183             64  23.3   32
# 3         89             66  28.1   21
# 4        137             40  43.1   33
# ..       ...            ...   ...  ...
# 763      101             76  32.9   63
# 764      122             70  36.8   27
# 765      121             72  26.2   30
# 766      126             60  30.1   47
# 767       93             70  30.4   23
#
# [768 rows x 4 columns]

# %%
df = df.drop(df.index[10:])
df
# Out:
#    Glucose  BloodPressure   BMI  Age
# 0      148             72  33.6   50
# 1       85             66  26.6   31
# 2      183             64  23.3   32
# 3       89             66  28.1   21
# 4      137             40  43.1   33
# 5      116             74  25.6   30
# 6       78             50  31.0   26
# 7      115              0  35.3   29
# 8      197             70  30.5   53
# 9      125             96   0.0   54

# %%
#create a line plot of different color for each feature
df.plot(kind='line',color=['red','blue','brown','green'])
#Set title to "Features responsible for diabetes"
plt.title("Features responsible for diabetes")
#Label x axis as "Observations"
plt.xlabel('Observations')
#Label y axis as "Values"
plt.ylabel('Values')
#Display the figure
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 df.plot(kind='line',color=['red','blue','brown','green'])
#       3 #Set title to "Features responsible for diabetes"
# ----> 4 plt.title("Features responsible for diabetes")
#       5 #Label x axis as "Observations"
#       6 plt.xlabel('Observations')
#
# TypeError: 'str' object is not callable

# %%
#create a line plot of different color for each feature
df.plot(kind='line', color=['red','blue','brown','green'],
marker='*',markersize=10,linewidth=3,linestyle="--")
# Set title to "Features responsible for diabetes"
plt.title('Features responsible for diabetes')
# Label x axis as "Oberservations"
plt.xlabel('Oberservations')
# Label y axis as "Values"
plt.ylabel('Values')
#Display the figure
plt.show()

# %%
#plots a bar chart
df.plot(kind='bar')
#set title, set xlabel and ylabel
plt.title=('diabetes prediction')
plt.xlabel('Obervations')
plt.ylabel('Values')
plt.show()

# %%
#Customising Bar Chart
df.plot(kind ='bar',title ='diabetes prediction',
color=['red','yellow','purple','pink'],edgecolor='Green', linewidth=2,
linestyle='--')
#set title, set xlabel and ylabel
plt.xlabel('Obervations')
plt.ylabel('Values')
plt.show()

# %%
x= df['Age']
y= df['Glucose']
plt.scatter(x,y)
plt.title('Diabetes Prediction')
plt.xlabel('Age')
plt.ylabel('Glucose')
plt.show()

# %%
#Customising Scatter Plot
x= df['Glucose']
y= df['Insulin']
plt.scatter(x,y,color='red',linewidth=2,marker='*',edgecolor='red')
plt.title('Diabetes Prediction')
plt.xlabel('Glucose')
plt.ylabel('Insulin')
plt.show()

# %%
df.plot(kind='hist',title='diabetes prediction')
plt.show()

# %%
#Customising Histogram
df.plot(kind='hist',edgecolor='Blue',linewidth=2,linestyle=':',fill=False,hatch='o')
plt.show()

# %%
df.plot(kind='pie',y='Glucose', legend=False,autopct="%.2f%%")
plt.show()

# %%
df.plot(kind='box')
#set title,xlabel,ylabel
plt.title('Diabetes Prediction')
plt.xlabel('Index')
plt.ylabel('Values')
plt.show()
